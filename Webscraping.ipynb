# %% [markdown]
# <a href="https://colab.research.google.com/github/vvvvvvss/WebScraping/blob/main/Webscraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests beautifulsoup4 pandas

# %%
import requests

url = "https://books.toscrape.com/"
response = requests.get(url)
html_content = response.content

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html_content, 'html.parser')

# %%
books = soup.find_all("article", class_="product_pod")

# %%
for book in books:
    title = book.find("h3").text.strip()
    price = book.find("p", class_="price_color").text.strip()
    rating = book.find("p", class_="star-rating").text.strip()
    print(f"Title: {title}, Price: {price}, Rating: {rating}")
# Out:
# Title: A Light in the ..., Price: £51.77, Rating:
# Title: Tipping the Velvet, Price: £53.74, Rating:
# Title: Soumission, Price: £50.10, Rating:
# Title: Sharp Objects, Price: £47.82, Rating:
# Title: Sapiens: A Brief History ..., Price: £54.23, Rating:
# Title: The Requiem Red, Price: £22.65, Rating:
# Title: The Dirty Little Secrets ..., Price: £33.34, Rating:
# Title: The Coming Woman: A ..., Price: £17.93, Rating:
# Title: The Boys in the ..., Price: £22.60, Rating:
# Title: The Black Maria, Price: £52.15, Rating:
# Title: Starving Hearts (Triangular Trade ..., Price: £13.99, Rating:
# Title: Shakespeare's Sonnets, Price: £20.66, Rating:
# Title: Set Me Free, Price: £17.46, Rating:
# Title: Scott Pilgrim's Precious Little ..., Price: £52.29, Rating:
# Title: Rip it Up and ..., Price: £35.02, Rating:
# Title: Our Band Could Be ..., Price: £57.25, Rating:
# Title: Olio, Price: £23.88, Rating:
# Title: Mesaerion: The Best Science ..., Price: £37.59, Rating:
# ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://free-proxy-list.net"
response = requests.get(url)

# %%
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')
    ip_addresses = []
    table = soup.find('table', id='proxylisttable')
    if table:
        rows = table.find_all('tr')
        for row in rows[1:]:
            cells = row.find_all('td')
            if cells:
                ip_address = cells[0].get_text().strip()
                ip_addresses.append(ip_address)


    if ip_addresses:
        print("Extracted IP Addresses:")
        for ip in ip_addresses:
            print(ip)
    else:
        print("No IP addresses found")
else:
    print("Failed to retrieve the page")


print(response.text)
# Out:
# No IP addresses found
# ...
